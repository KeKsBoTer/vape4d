# %%
from vape import viewer
import numpy as np
from matplotlib import pyplot as plt

# %%
viewer(
    np.random.rand(1,1,32,32,32),
    plt.get_cmap("viridis"),   
)
# Out:
#     <div>
#         <iframe id="vape_canvas_2946234591" src="http://localhost:5500/public/index.html?inline" width="800" height="600" frameBorder="0" sandbox="allow-same-origin allow-scripts"></iframe>
#     </div>
#     <script>
#
#         window.addEventListener(
#             "message",
#             (event) => {
#                 if (event.data !== "ready") {
#                     return;
#                 }
#                 let data_decoded = Uint8Array.from(atob("..."), c => c.charCodeAt(0));
#                 let cmap_decoded = Uint8Array.from(atob("..."), c => c.charCodeAt(0));
#                 const iframe = document.getElementById("vape_canvas_2946234591");
#                 if (iframe === null) return;
#                 iframe.contentWindow.postMessage({
#                     volume: data_decoded,
#                     cmap: cmap_decoded,
#                     settings: {"width": 800, "height": 600, "background_color": [0.0, 0.0, 0.0, 1.0], "show_colormap_editor": false, "show_volume_info": false, "vmin": null, "vmax": null}
#                 },
#                 "*");
#             },
#             false,
#         );
#     </script>
